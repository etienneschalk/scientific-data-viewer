# %%
PATH_TO_CDF_FILE = "/home/eschalk/Downloads/SW_OPER_MAGA_LR_1B_20141031T000000_20141031T235959_0602_ASM_VFM_IC.cdf"

# %%
import xarray as xr 

try: 
    xds = xr.open_dataset(
        PATH_TO_CDF_FILE
        )
except ValueError as err:
    print(repr(err))

# %%
# !pip install cdflib

# %%
import cdflib.xarray

xds = cdflib.xarray.cdf_to_xarray(PATH_TO_CDF_FILE)
print(xds)
